# %%
import subprocess
# result = subprocess.run(["python", "submit_mnist_experiment.py"], text=True, capture_output=True)
# print(result.stdout)
# print(result.stder~r)

# %%
import os
import subprocess

# Set the environment variable to use UTF-8 encoding
env = os.environ.copy()
env["PYTHONIOENCODING"] = "utf-8"

# Run the subprocess with the modified environment
result = subprocess.run(
    ["python", "submit_mnist_experiment.py"],
    text=True,
    capture_output=True, errors= 'ignore',
    env=env  # Pass the modified environment
)

# Print the output and error (if any)
print(result.stdout)
print(result.stderr)
# Out:
# Exception in thread Thread-68:
# Traceback (most recent call last):
#   File "c:\Users\peter\AppData\Local\Programs\Python\Python39\lib\threading.py", line 950, in _bootstrap_inner
#     self.run()
#   File "C:\Users\peter\AppData\Roaming\Python\Python39\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\peter\AppData\Local\Programs\Python\Python39\lib\threading.py", line 888, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\peter\AppData\Local\Programs\Python\Python39\lib\subprocess.py", line 1475, in _readerthread
#     buffer.append(fh.read())
#   File "c:\Users\peter\AppData\Local\Programs\Python\Python39\lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 496: character maps to <undefined>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 9
#       6 env["PYTHONIOENCODING"] = "utf-8"
#       8 # Run the subprocess with the modified environment
# ----> 9 result = subprocess.run(
#      10     ["python", "submit_mnist_experiment.py"],
#      11     text=True,
#      12     capture_output=True,
#      13     env=env  # Pass the modified environment
#      14 )
#      16 # Print the output and error (if any)
#      17 print(result.stdout)
#
# File c:\Users\peter\AppData\Local\Programs\Python\Python39\lib\subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
# --> 503         stdout, stderr = process.communicate(input, timeout=timeout)
#     504     except TimeoutExpired as exc:
#     505         process.kill()
#
# File c:\Users\peter\AppData\Local\Programs\Python\Python39\lib\subprocess.py:1130, in Popen.communicate(self, input, timeout)
#    1127     endtime = None
#    1129 try:
# -> 1130     stdout, stderr = self._communicate(input, endtime, timeout)
#    1131 except KeyboardInterrupt:
#    1132     # https://bugs.python.org/issue25942
#    1133     # See the detailed comment in .wait().
#    1134     if timeout is not None:
#
# File c:\Users\peter\AppData\Local\Programs\Python\Python39\lib\subprocess.py:1525, in Popen._communicate(self, input, endtime, orig_timeout)
#    1523 # All data exchanged.  Translate lists into strings.
#    1524 if stdout is not None:
# -> 1525     stdout = stdout[0]
#    1526 if stderr is not None:
#    1527     stderr = stderr[0]
#
# IndexError: list index out of range

# %%
result = subprocess.run(["python", "submit_mnist_experiment.py"], text=True, capture_output=True,errors ='ignore',encoding="utf-8")#,errors="ignore")
# subprocess.run(["python", "make_table_3.py"])

# %%
print(result.stdout)
# print(result.stderr)
# Out:
# d:\Maths_Y4\Project\Bayesian-Neural-Network-Project\Rebuilding_Slang
# python d:\Maths_Y4\Project\Bayesian-Neural-Network-Project\Rebuilding_Slang\run_experiment.py --name="slang_mnist_experiment" --variant="L_1" --method="SLANG_COMPLETE" --cv=0
# args: Namespace(name='slang_mnist_experiment', variant='L_1', method='SLANG_COMPLETE', cv=0)
#
#   0%|          | 0.00/9.91M [00:00<?, ?B/s]
#   0%|          | 32.8k/9.91M [00:00<00:33, 296kB/s]
#   1%|          | 98.3k/9.91M [00:00<00:20, 482kB/s]
#   2%|#         | 197k/9.91M [00:00<00:14, 680kB/s]
#   3%|#         | 328k/9.91M [00:00<00:10, 891kB/s]
#   6%|#         | 590k/9.91M [00:00<00:06, 1.45MB/s]
#  12%|##        | 1.15M/9.91M [00:00<00:03, 2.70MB/s]
#  16%|##        | 1.61M/9.91M [00:00<00:03, 2.59MB/s]
#  28%|###       | 2.82M/9.91M [00:00<00:01, 4.60MB/s]
#  38%|####      | 3.80M/9.91M [00:01<00:01, 5.14MB/s]
#  49%|#####     | 4.85M/9.91M [00:01<00:00, 6.39MB/s]
#  56%|######    | 5.54M/9.91M [00:01<00:00, 6.48MB/s]
#  63%|#######   | 6.26M/9.91M [00:01<00:00, 6.64MB/s]
#  70%|#######   | 6.95M/9.91M [00:01<00:00, 6.29MB/s]
#  77%|########  | 7.60M/9.91M [00:01<00:00, 5.69MB/s]
#  83%|######### | 8.19M/9.91M [00:01<00:00, 5.35MB/s]
#  88%|######### | 8.75M/9.91M [00:01<00:00, 5.01MB/s]
#  94%|##########| 9.27M/9.91M [00:02<00:00, 4.88MB/s]
#  99%|##########| 9.80M/9.91M [00:02<00:00, 4.95MB/s]
# 100%|##########| 9.91M/9.91M [00:02<00:00, 4.45MB/s]
#
#   0%|          | 0.00/28.9k [00:00<?, ?B/s]
# 100%|##########| 28.9k/28.9k [00:00<00:00, 270kB/s]
# 100%|##########| 28.9k/28.9k [00:00<00:00, 268kB/s]
#
#   0%|          | 0.00/1.65M [00:00<?, ?B/s]
#   2%|#         | 32.8k/1.65M [00:00<00:05, 286kB/s]
#   6%|#         | 98.3k/1.65M [00:00<00:03, 462kB/s]
#  12%|##        | 197k/1.65M [00:00<00:02, 661kB/s]
#  20%|##        | 328k/1.65M [00:00<00:01, 881kB/s]
#  40%|####      | 655k/1.65M [00:00<00:00, 1.64MB/s]
#  79%|########  | 1.31M/1.65M [00:00<00:00, 3.10MB/s]
# 100%|##########| 1.65M/1.65M [00:00<00:00, 2.37MB/s]
#
#   0%|          | 0.00/4.54k [00:00<?, ?B/s]
# 100%|##########| 4.54k/4.54k [00:00<00:00, 4.57MB/s]
# c:\Users\peter\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch [1/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3514, test_pred_logloss: 2.3019, test_pred_accuracy: 0.1064
# Epoch [1/100], Objective: 2.4557
# Epoch [2/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3388, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [2/100], Objective: 2.3013
# Epoch [3/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3302, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [3/100], Objective: 2.3012
# Epoch [4/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3239, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [4/100], Objective: 2.3012
# Epoch [5/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3191, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [5/100], Objective: 2.3012
# Epoch [6/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3154, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [6/100], Objective: 2.3012
# Epoch [7/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3127, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [7/100], Objective: 2.3012
# Epoch [8/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3107, test_pred_logloss: 2.3019, test_pred_accuracy: 0.1064
# Epoch [8/100], Objective: 2.3012
# Epoch [9/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3092, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [9/100], Objective: 2.3012
# Epoch [10/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3080, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [10/100], Objective: 2.3012
# Epoch [11/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3071, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [11/100], Objective: 2.3012
# Epoch [12/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3065, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [12/100], Objective: 2.3011
# Epoch [13/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3060, test_pred_logloss: 2.3021, test_pred_accuracy: 0.1064
# Epoch [13/100], Objective: 2.3011
# Epoch [14/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3056, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [14/100], Objective: 2.3012
# Epoch [15/100], train_pred_logloss: 2.3011, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3053, test_pred_logloss: 2.3020, test_pred_accuracy: 0.1064
# Epoch [15/100], Objective: 2.3011
# Epoch [16/100], train_pred_logloss: 2.2999, train_pred_accuracy: 0.1136, elbo_neg_ave: 2.3049, test_pred_logloss: 2.3017, test_pred_accuracy: 0.1064
# Epoch [16/100], Objective: 2.3011
# Epoch [17/100], train_pred_logloss: 2.1990, train_pred_accuracy: 0.2083, elbo_neg_ave: 2.2191, test_pred_logloss: 2.1768, test_pred_accuracy: 0.2016
# Epoch [17/100], Objective: 2.2974
# Epoch [18/100], train_pred_logloss: 2.0109, train_pred_accuracy: 0.2208, elbo_neg_ave: 2.0215, test_pred_logloss: 1.9995, test_pred_accuracy: 0.2144
# Epoch [18/100], Objective: 2.0690
# Epoch [19/100], train_pred_logloss: 1.9622, train_pred_accuracy: 0.2273, elbo_neg_ave: 1.9726, test_pred_logloss: 1.9496, test_pred_accuracy: 0.2232
# Epoch [19/100], Objective: 1.9905
# Epoch [20/100], train_pred_logloss: 1.9289, train_pred_accuracy: 0.2316, elbo_neg_ave: 1.9393, test_pred_logloss: 1.9120, test_pred_accuracy: 0.2292
# Epoch [20/100], Objective: 1.9485
# Epoch [21/100], train_pred_logloss: 1.9027, train_pred_accuracy: 0.2405, elbo_neg_ave: 1.9138, test_pred_logloss: 1.8883, test_pred_accuracy: 0.2337
# Epoch [21/100], Objective: 1.9186
# Epoch [22/100], train_pred_logloss: 1.8809, train_pred_accuracy: 0.2555, elbo_neg_ave: 1.8949, test_pred_logloss: 1.8670, test_pred_accuracy: 0.2428
# Epoch [22/100], Objective: 1.8967
# Epoch [23/100], train_pred_logloss: 1.8669, train_pred_accuracy: 0.2533, elbo_neg_ave: 1.8800, test_pred_logloss: 1.8507, test_pred_accuracy: 0.2546
# Epoch [23/100], Objective: 1.8781
# Epoch [24/100], train_pred_logloss: 1.8528, train_pred_accuracy: 0.2667, elbo_neg_ave: 1.8673, test_pred_logloss: 1.8396, test_pred_accuracy: 0.2588
# Epoch [24/100], Objective: 1.8634
# Epoch [25/100], train_pred_logloss: 1.8409, train_pred_accuracy: 0.2731, elbo_neg_ave: 1.8534, test_pred_logloss: 1.8255, test_pred_accuracy: 0.2630
# Epoch [25/100], Objective: 1.8497
# Epoch [26/100], train_pred_logloss: 1.8291, train_pred_accuracy: 0.2822, elbo_neg_ave: 1.8421, test_pred_logloss: 1.8123, test_pred_accuracy: 0.2715
# Epoch [26/100], Objective: 1.8370
# Epoch [27/100], train_pred_logloss: 1.8162, train_pred_accuracy: 0.2776, elbo_neg_ave: 1.8305, test_pred_logloss: 1.8017, test_pred_accuracy: 0.2755
# Epoch [27/100], Objective: 1.8249
# Epoch [28/100], train_pred_logloss: 1.8044, train_pred_accuracy: 0.2931, elbo_neg_ave: 1.8175, test_pred_logloss: 1.7904, test_pred_accuracy: 0.2774
# Epoch [28/100], Objective: 1.8130
# Epoch [29/100], train_pred_logloss: 1.7916, train_pred_accuracy: 0.2982, elbo_neg_ave: 1.8065, test_pred_logloss: 1.7762, test_pred_accuracy: 0.2860
# Epoch [29/100], Objective: 1.8011
# Epoch [30/100], train_pred_logloss: 1.7808, train_pred_accuracy: 0.3014, elbo_neg_ave: 1.7951, test_pred_logloss: 1.7676, test_pred_accuracy: 0.2915
# Epoch [30/100], Objective: 1.7900
# Epoch [31/100], train_pred_logloss: 1.7706, train_pred_accuracy: 0.3063, elbo_neg_ave: 1.7857, test_pred_logloss: 1.7578, test_pred_accuracy: 0.2897
# Epoch [31/100], Objective: 1.7797
# Epoch [32/100], train_pred_logloss: 1.7627, train_pred_accuracy: 0.3085, elbo_neg_ave: 1.7773, test_pred_logloss: 1.7472, test_pred_accuracy: 0.2963
# Epoch [32/100], Objective: 1.7703
# Epoch [33/100], train_pred_logloss: 1.7532, train_pred_accuracy: 0.3114, elbo_neg_ave: 1.7677, test_pred_logloss: 1.7406, test_pred_accuracy: 0.3012
# Epoch [33/100], Objective: 1.7604
# Epoch [34/100], train_pred_logloss: 1.7447, train_pred_accuracy: 0.3127, elbo_neg_ave: 1.7600, test_pred_logloss: 1.7286, test_pred_accuracy: 0.2993
# Epoch [34/100], Objective: 1.7517
# Epoch [35/100], train_pred_logloss: 1.7247, train_pred_accuracy: 0.3182, elbo_neg_ave: 1.7426, test_pred_logloss: 1.7105, test_pred_accuracy: 0.3061
# Epoch [35/100], Objective: 1.7409
# Epoch [36/100], train_pred_logloss: 1.6872, train_pred_accuracy: 0.3390, elbo_neg_ave: 1.7056, test_pred_logloss: 1.6690, test_pred_accuracy: 0.3272
# Epoch [36/100], Objective: 1.7112
# Epoch [37/100], train_pred_logloss: 1.6585, train_pred_accuracy: 0.3506, elbo_neg_ave: 1.6765, test_pred_logloss: 1.6431, test_pred_accuracy: 0.3401
# Epoch [37/100], Objective: 1.6771
# Epoch [38/100], train_pred_logloss: 1.6384, train_pred_accuracy: 0.3575, elbo_neg_ave: 1.6586, test_pred_logloss: 1.6242, test_pred_accuracy: 0.3509
# Epoch [38/100], Objective: 1.6533
# Epoch [39/100], train_pred_logloss: 1.6217, train_pred_accuracy: 0.3678, elbo_neg_ave: 1.6430, test_pred_logloss: 1.6089, test_pred_accuracy: 0.3653
# Epoch [39/100], Objective: 1.6345
# Epoch [40/100], train_pred_logloss: 1.6081, train_pred_accuracy: 0.3828, elbo_neg_ave: 1.6288, test_pred_logloss: 1.5943, test_pred_accuracy: 0.3748
# Epoch [40/100], Objective: 1.6187
# Epoch [41/100], train_pred_logloss: 1.5966, train_pred_accuracy: 0.3848, elbo_neg_ave: 1.6175, test_pred_logloss: 1.5797, test_pred_accuracy: 0.3882
# Epoch [41/100], Objective: 1.6060
# Epoch [42/100], train_pred_logloss: 1.5224, train_pred_accuracy: 0.3938, elbo_neg_ave: 1.5475, test_pred_logloss: 1.5055, test_pred_accuracy: 0.3887
# Epoch [42/100], Objective: 1.5758
# Epoch [43/100], train_pred_logloss: 1.4963, train_pred_accuracy: 0.4047, elbo_neg_ave: 1.5199, test_pred_logloss: 1.4779, test_pred_accuracy: 0.4017
# Epoch [43/100], Objective: 1.5139
# Epoch [44/100], train_pred_logloss: 1.4823, train_pred_accuracy: 0.4037, elbo_neg_ave: 1.5053, test_pred_logloss: 1.4658, test_pred_accuracy: 0.4084
# Epoch [44/100], Objective: 1.4929
# Epoch [45/100], train_pred_logloss: 1.4705, train_pred_accuracy: 0.4129, elbo_neg_ave: 1.4939, test_pred_logloss: 1.4549, test_pred_accuracy: 0.4142
# Epoch [45/100], Objective: 1.4803
# Epoch [46/100], train_pred_logloss: 1.4613, train_pred_accuracy: 0.4115, elbo_neg_ave: 1.4853, test_pred_logloss: 1.4437, test_pred_accuracy: 0.4152
# Epoch [46/100], Objective: 1.4684
# Epoch [47/100], train_pred_logloss: 1.4517, train_pred_accuracy: 0.4182, elbo_neg_ave: 1.4762, test_pred_logloss: 1.4378, test_pred_accuracy: 0.4154
# Epoch [47/100], Objective: 1.4594
# Epoch [48/100], train_pred_logloss: 1.4435, train_pred_accuracy: 0.4188, elbo_neg_ave: 1.4682, test_pred_logloss: 1.4291, test_pred_accuracy: 0.4214
# Epoch [48/100], Objective: 1.4518
# Epoch [49/100], train_pred_logloss: 1.4366, train_pred_accuracy: 0.4204, elbo_neg_ave: 1.4615, test_pred_logloss: 1.4224, test_pred_accuracy: 0.4231
# Epoch [49/100], Objective: 1.4438
# Epoch [50/100], train_pred_logloss: 1.4298, train_pred_accuracy: 0.4442, elbo_neg_ave: 1.4545, test_pred_logloss: 1.4175, test_pred_accuracy: 0.4455
# Epoch [50/100], Objective: 1.4363
# Epoch [51/100], train_pred_logloss: 1.4209, train_pred_accuracy: 0.4419, elbo_neg_ave: 1.4471, test_pred_logloss: 1.4080, test_pred_accuracy: 0.4461
# Epoch [51/100], Objective: 1.4284
# Epoch [52/100], train_pred_logloss: 1.4150, train_pred_accuracy: 0.4452, elbo_neg_ave: 1.4418, test_pred_logloss: 1.4007, test_pred_accuracy: 0.4487
# Epoch [52/100], Objective: 1.4215
# Epoch [53/100], train_pred_logloss: 1.4086, train_pred_accuracy: 0.4494, elbo_neg_ave: 1.4335, test_pred_logloss: 1.3939, test_pred_accuracy: 0.4506
# Epoch [53/100], Objective: 1.4140
# Epoch [54/100], train_pred_logloss: 1.4003, train_pred_accuracy: 0.4505, elbo_neg_ave: 1.4279, test_pred_logloss: 1.3888, test_pred_accuracy: 0.4547
# Epoch [54/100], Objective: 1.4079
# Epoch [55/100], train_pred_logloss: 1.3954, train_pred_accuracy: 0.4478, elbo_neg_ave: 1.4212, test_pred_logloss: 1.3845, test_pred_accuracy: 0.4534
# Epoch [55/100], Objective: 1.4020
# Epoch [56/100], train_pred_logloss: 1.3885, train_pred_accuracy: 0.4564, elbo_neg_ave: 1.4178, test_pred_logloss: 1.3784, test_pred_accuracy: 0.4566
# Epoch [56/100], Objective: 1.3957
# Epoch [57/100], train_pred_logloss: 1.3851, train_pred_accuracy: 0.4524, elbo_neg_ave: 1.4129, test_pred_logloss: 1.3742, test_pred_accuracy: 0.4564
# Epoch [57/100], Objective: 1.3913
# Epoch [58/100], train_pred_logloss: 1.3791, train_pred_accuracy: 0.4542, elbo_neg_ave: 1.4098, test_pred_logloss: 1.3672, test_pred_accuracy: 0.4589
# Epoch [58/100], Objective: 1.3862
# Epoch [59/100], train_pred_logloss: 1.3758, train_pred_accuracy: 0.4538, elbo_neg_ave: 1.4033, test_pred_logloss: 1.3619, test_pred_accuracy: 0.4591
# Epoch [59/100], Objective: 1.3815
# Epoch [60/100], train_pred_logloss: 1.3700, train_pred_accuracy: 0.4582, elbo_neg_ave: 1.3981, test_pred_logloss: 1.3598, test_pred_accuracy: 0.4651
# Epoch [60/100], Objective: 1.3765
# Epoch [61/100], train_pred_logloss: 1.3647, train_pred_accuracy: 0.4611, elbo_neg_ave: 1.3935, test_pred_logloss: 1.3520, test_pred_accuracy: 0.4633
# Epoch [61/100], Objective: 1.3717
# Epoch [62/100], train_pred_logloss: 1.3624, train_pred_accuracy: 0.4606, elbo_neg_ave: 1.3919, test_pred_logloss: 1.3488, test_pred_accuracy: 0.4634
# Epoch [62/100], Objective: 1.3683
# Epoch [63/100], train_pred_logloss: 1.3583, train_pred_accuracy: 0.4624, elbo_neg_ave: 1.3869, test_pred_logloss: 1.3436, test_pred_accuracy: 0.4651
# Epoch [63/100], Objective: 1.3642
# Epoch [64/100], train_pred_logloss: 1.3560, train_pred_accuracy: 0.4633, elbo_neg_ave: 1.3851, test_pred_logloss: 1.3398, test_pred_accuracy: 0.4744
# Epoch [64/100], Objective: 1.3599
# Epoch [65/100], train_pred_logloss: 1.3498, train_pred_accuracy: 0.4638, elbo_neg_ave: 1.3798, test_pred_logloss: 1.3351, test_pred_accuracy: 0.4725
# Epoch [65/100], Objective: 1.3570
# Epoch [66/100], train_pred_logloss: 1.3473, train_pred_accuracy: 0.4636, elbo_neg_ave: 1.3763, test_pred_logloss: 1.3319, test_pred_accuracy: 0.4708
# Epoch [66/100], Objective: 1.3530
# Epoch [67/100], train_pred_logloss: 1.3444, train_pred_accuracy: 0.4670, elbo_neg_ave: 1.3742, test_pred_logloss: 1.3269, test_pred_accuracy: 0.4720
# Epoch [67/100], Objective: 1.3498
# Epoch [68/100], train_pred_logloss: 1.3401, train_pred_accuracy: 0.4741, elbo_neg_ave: 1.3692, test_pred_logloss: 1.3195, test_pred_accuracy: 0.4770
# Epoch [68/100], Objective: 1.3460
# Epoch [69/100], train_pred_logloss: 1.3378, train_pred_accuracy: 0.4726, elbo_neg_ave: 1.3682, test_pred_logloss: 1.3198, test_pred_accuracy: 0.4766
# Epoch [69/100], Objective: 1.3422
# Epoch [70/100], train_pred_logloss: 1.3355, train_pred_accuracy: 0.4708, elbo_neg_ave: 1.3641, test_pred_logloss: 1.3171, test_pred_accuracy: 0.4821
# Epoch [70/100], Objective: 1.3393
# Epoch [71/100], train_pred_logloss: 1.3315, train_pred_accuracy: 0.4721, elbo_neg_ave: 1.3622, test_pred_logloss: 1.3115, test_pred_accuracy: 0.4802
# Epoch [71/100], Objective: 1.3360
# Epoch [72/100], train_pred_logloss: 1.3286, train_pred_accuracy: 0.4727, elbo_neg_ave: 1.3582, test_pred_logloss: 1.3080, test_pred_accuracy: 0.4839
# Epoch [72/100], Objective: 1.3337
# Epoch [73/100], train_pred_logloss: 1.3256, train_pred_accuracy: 0.4756, elbo_neg_ave: 1.3557, test_pred_logloss: 1.3034, test_pred_accuracy: 0.4836
# Epoch [73/100], Objective: 1.3302
# Epoch [74/100], train_pred_logloss: 1.3226, train_pred_accuracy: 0.4766, elbo_neg_ave: 1.3529, test_pred_logloss: 1.3015, test_pred_accuracy: 0.4823
# Epoch [74/100], Objective: 1.3275
# Epoch [75/100], train_pred_logloss: 1.3203, train_pred_accuracy: 0.4759, elbo_neg_ave: 1.3522, test_pred_logloss: 1.2976, test_pred_accuracy: 0.4832
# Epoch [75/100], Objective: 1.3246
# Epoch [76/100], train_pred_logloss: 1.3174, train_pred_accuracy: 0.4794, elbo_neg_ave: 1.3491, test_pred_logloss: 1.2917, test_pred_accuracy: 0.4857
# Epoch [76/100], Objective: 1.3217
# Epoch [77/100], train_pred_logloss: 1.3163, train_pred_accuracy: 0.4798, elbo_neg_ave: 1.3470, test_pred_logloss: 1.2909, test_pred_accuracy: 0.4875
# Epoch [77/100], Objective: 1.3191
# Epoch [78/100], train_pred_logloss: 1.3121, train_pred_accuracy: 0.4780, elbo_neg_ave: 1.3442, test_pred_logloss: 1.2880, test_pred_accuracy: 0.4876
# Epoch [78/100], Objective: 1.3166
# Epoch [79/100], train_pred_logloss: 1.3090, train_pred_accuracy: 0.4816, elbo_neg_ave: 1.3415, test_pred_logloss: 1.2854, test_pred_accuracy: 0.4928
# Epoch [79/100], Objective: 1.3142
# Epoch [80/100], train_pred_logloss: 1.3078, train_pred_accuracy: 0.4817, elbo_neg_ave: 1.3397, test_pred_logloss: 1.2812, test_pred_accuracy: 0.4930
# Epoch [80/100], Objective: 1.3118
# Epoch [81/100], train_pred_logloss: 1.3048, train_pred_accuracy: 0.4858, elbo_neg_ave: 1.3370, test_pred_logloss: 1.2803, test_pred_accuracy: 0.4984
# Epoch [81/100], Objective: 1.3095
# Epoch [82/100], train_pred_logloss: 1.3039, train_pred_accuracy: 0.4828, elbo_neg_ave: 1.3351, test_pred_logloss: 1.2782, test_pred_accuracy: 0.4938
# Epoch [82/100], Objective: 1.3076
# Epoch [83/100], train_pred_logloss: 1.3005, train_pred_accuracy: 0.4858, elbo_neg_ave: 1.3325, test_pred_logloss: 1.2736, test_pred_accuracy: 0.4949
# Epoch [83/100], Objective: 1.3053
# Epoch [84/100], train_pred_logloss: 1.2992, train_pred_accuracy: 0.4851, elbo_neg_ave: 1.3309, test_pred_logloss: 1.2736, test_pred_accuracy: 0.4974
# Epoch [84/100], Objective: 1.3030
# Epoch [85/100], train_pred_logloss: 1.2963, train_pred_accuracy: 0.4845, elbo_neg_ave: 1.3285, test_pred_logloss: 1.2694, test_pred_accuracy: 0.4983
# Epoch [85/100], Objective: 1.3005
# Epoch [86/100], train_pred_logloss: 1.2949, train_pred_accuracy: 0.4847, elbo_neg_ave: 1.3285, test_pred_logloss: 1.2691, test_pred_accuracy: 0.4981
# Epoch [86/100], Objective: 1.2990
# Epoch [87/100], train_pred_logloss: 1.2938, train_pred_accuracy: 0.4866, elbo_neg_ave: 1.3263, test_pred_logloss: 1.2668, test_pred_accuracy: 0.4999
# Epoch [87/100], Objective: 1.2975
# Epoch [88/100], train_pred_logloss: 1.2924, train_pred_accuracy: 0.4904, elbo_neg_ave: 1.3245, test_pred_logloss: 1.2641, test_pred_accuracy: 0.4981
# Epoch [88/100], Objective: 1.2954
# Epoch [89/100], train_pred_logloss: 1.2911, train_pred_accuracy: 0.4852, elbo_neg_ave: 1.3232, test_pred_logloss: 1.2628, test_pred_accuracy: 0.5004
# Epoch [89/100], Objective: 1.2937
# Epoch [90/100], train_pred_logloss: 1.2887, train_pred_accuracy: 0.4872, elbo_neg_ave: 1.3208, test_pred_logloss: 1.2603, test_pred_accuracy: 0.5005
# Epoch [90/100], Objective: 1.2923
# Epoch [91/100], train_pred_logloss: 1.2865, train_pred_accuracy: 0.4884, elbo_neg_ave: 1.3192, test_pred_logloss: 1.2582, test_pred_accuracy: 0.5032
# Epoch [91/100], Objective: 1.2911
# Epoch [92/100], train_pred_logloss: 1.2849, train_pred_accuracy: 0.4872, elbo_neg_ave: 1.3178, test_pred_logloss: 1.2544, test_pred_accuracy: 0.5002
# Epoch [92/100], Objective: 1.2889
# Epoch [93/100], train_pred_logloss: 1.2839, train_pred_accuracy: 0.4890, elbo_neg_ave: 1.3168, test_pred_logloss: 1.2553, test_pred_accuracy: 0.5027
# Epoch [93/100], Objective: 1.2870
# Epoch [94/100], train_pred_logloss: 1.2813, train_pred_accuracy: 0.4878, elbo_neg_ave: 1.3144, test_pred_logloss: 1.2517, test_pred_accuracy: 0.5048
# Epoch [94/100], Objective: 1.2859
# Epoch [95/100], train_pred_logloss: 1.2801, train_pred_accuracy: 0.4897, elbo_neg_ave: 1.3139, test_pred_logloss: 1.2533, test_pred_accuracy: 0.5032
# Epoch [95/100], Objective: 1.2845
# Epoch [96/100], train_pred_logloss: 1.2791, train_pred_accuracy: 0.4912, elbo_neg_ave: 1.3134, test_pred_logloss: 1.2498, test_pred_accuracy: 0.4991
# Epoch [96/100], Objective: 1.2830
# Epoch [97/100], train_pred_logloss: 1.2784, train_pred_accuracy: 0.4905, elbo_neg_ave: 1.3128, test_pred_logloss: 1.2489, test_pred_accuracy: 0.5048
# Epoch [97/100], Objective: 1.2815
# Epoch [98/100], train_pred_logloss: 1.2766, train_pred_accuracy: 0.4912, elbo_neg_ave: 1.3100, test_pred_logloss: 1.2471, test_pred_accuracy: 0.5040
# Epoch [98/100], Objective: 1.2801
# Epoch [99/100], train_pred_logloss: 1.2754, train_pred_accuracy: 0.4892, elbo_neg_ave: 1.3097, test_pred_logloss: 1.2441, test_pred_accuracy: 0.5060
# Epoch [99/100], Objective: 1.2784
# Epoch [100/100], train_pred_logloss: 1.2738, train_pred_accuracy: 0.4918, elbo_neg_ave: 1.3074, test_pred_logloss: 1.2442, test_pred_accuracy: 0.5021
# Epoch [100/100], Objective: 1.2770
# Epoch [1/100], train_pred_logloss: 1.2666, train_pred_accuracy: 0.4930, elbo_neg_ave: 1.2952, test_pred_logloss: 1.2851, test_pred_accuracy: 0.4825
# Epoch [1/100], Objective: 1.2705
# Epoch [2/100], train_pred_logloss: 1.2648, train_pred_accuracy: 0.4927, elbo_neg_ave: 1.2942, test_pred_logloss: 1.2846, test_pred_accuracy: 0.4880
# Epoch [2/100], Objective: 1.2684
# Epoch [3/100], train_pred_logloss: 1.2630, train_pred_accuracy: 0.4936, elbo_neg_ave: 1.2921, test_pred_logloss: 1.2819, test_pred_accuracy: 0.4816
# Epoch [3/100], Objective: 1.2662
# Epoch [4/100], train_pred_logloss: 1.2611, train_pred_accuracy: 0.4963, elbo_neg_ave: 1.2897, test_pred_logloss: 1.2800, test_pred_accuracy: 0.4852
# Epoch [4/100], Objective: 1.2644
# Epoch [5/100], train_pred_logloss: 1.2593, train_pred_accuracy: 0.4949, elbo_neg_ave: 1.2877, test_pred_logloss: 1.2800, test_pred_accuracy: 0.4862
# Epoch [5/100], Objective: 1.2624
# Epoch [6/100], train_pred_logloss: 1.2584, train_pred_accuracy: 0.4981, elbo_neg_ave: 1.2873, test_pred_logloss: 1.2776, test_pred_accuracy: 0.4921
# Epoch [6/100], Objective: 1.2613
# Epoch [7/100], train_pred_logloss: 1.2563, train_pred_accuracy: 0.4988, elbo_neg_ave: 1.2855, test_pred_logloss: 1.2748, test_pred_accuracy: 0.5010
# Epoch [7/100], Objective: 1.2594
# Epoch [8/100], train_pred_logloss: 1.2550, train_pred_accuracy: 0.4982, elbo_neg_ave: 1.2841, test_pred_logloss: 1.2742, test_pred_accuracy: 0.4924
# Epoch [8/100], Objective: 1.2575
# Epoch [9/100], train_pred_logloss: 1.2531, train_pred_accuracy: 0.4983, elbo_neg_ave: 1.2824, test_pred_logloss: 1.2727, test_pred_accuracy: 0.5002
# Epoch [9/100], Objective: 1.2561
# Epoch [10/100], train_pred_logloss: 1.2503, train_pred_accuracy: 0.5044, elbo_neg_ave: 1.2810, test_pred_logloss: 1.2708, test_pred_accuracy: 0.5051
# Epoch [10/100], Objective: 1.2547
# Epoch [11/100], train_pred_logloss: 1.2505, train_pred_accuracy: 0.5049, elbo_neg_ave: 1.2799, test_pred_logloss: 1.2671, test_pred_accuracy: 0.5031
# Epoch [11/100], Objective: 1.2530
# Epoch [12/100], train_pred_logloss: 1.2488, train_pred_accuracy: 0.5057, elbo_neg_ave: 1.2789, test_pred_logloss: 1.2681, test_pred_accuracy: 0.5025
# Epoch [12/100], Objective: 1.2517
# Epoch [13/100], train_pred_logloss: 1.2468, train_pred_accuracy: 0.5053, elbo_neg_ave: 1.2780, test_pred_logloss: 1.2671, test_pred_accuracy: 0.5089
# Epoch [13/100], Objective: 1.2500
# Epoch [14/100], train_pred_logloss: 1.2465, train_pred_accuracy: 0.5054, elbo_neg_ave: 1.2759, test_pred_logloss: 1.2656, test_pred_accuracy: 0.5123
# Epoch [14/100], Objective: 1.2489
# Epoch [15/100], train_pred_logloss: 1.2440, train_pred_accuracy: 0.5113, elbo_neg_ave: 1.2751, test_pred_logloss: 1.2631, test_pred_accuracy: 0.5081
# Epoch [15/100], Objective: 1.2471
# Epoch [16/100], train_pred_logloss: 1.2430, train_pred_accuracy: 0.5098, elbo_neg_ave: 1.2738, test_pred_logloss: 1.2607, test_pred_accuracy: 0.5075
# Epoch [16/100], Objective: 1.2464
# Epoch [17/100], train_pred_logloss: 1.2424, train_pred_accuracy: 0.5137, elbo_neg_ave: 1.2731, test_pred_logloss: 1.2586, test_pred_accuracy: 0.5191
# Epoch [17/100], Objective: 1.2459
# Epoch [18/100], train_pred_logloss: 1.2409, train_pred_accuracy: 0.5116, elbo_neg_ave: 1.2723, test_pred_logloss: 1.2599, test_pred_accuracy: 0.5098
# Epoch [18/100], Objective: 1.2442
# Epoch [19/100], train_pred_logloss: 1.2396, train_pred_accuracy: 0.5114, elbo_neg_ave: 1.2701, test_pred_logloss: 1.2549, test_pred_accuracy: 0.5125
# Epoch [19/100], Objective: 1.2429
# Epoch [20/100], train_pred_logloss: 1.2391, train_pred_accuracy: 0.5104, elbo_neg_ave: 1.2703, test_pred_logloss: 1.2559, test_pred_accuracy: 0.5111
# Epoch [20/100], Objective: 1.2422
# Epoch [21/100], train_pred_logloss: 1.2374, train_pred_accuracy: 0.5147, elbo_neg_ave: 1.2679, test_pred_logloss: 1.2535, test_pred_accuracy: 0.5165
# Epoch [21/100], Objective: 1.2407
# Epoch [22/100], train_pred_logloss: 1.2368, train_pred_accuracy: 0.5166, elbo_neg_ave: 1.2680, test_pred_logloss: 1.2521, test_pred_accuracy: 0.5151
# Epoch [22/100], Objective: 1.2403
# Epoch [23/100], train_pred_logloss: 1.2360, train_pred_accuracy: 0.5121, elbo_neg_ave: 1.2661, test_pred_logloss: 1.2529, test_pred_accuracy: 0.5151
# Epoch [23/100], Objective: 1.2391
# Epoch [24/100], train_pred_logloss: 1.2352, train_pred_accuracy: 0.5150, elbo_neg_ave: 1.2658, test_pred_logloss: 1.2506, test_pred_accuracy: 0.5204
# Epoch [24/100], Objective: 1.2384
# Epoch [25/100], train_pred_logloss: 1.2341, train_pred_accuracy: 0.5158, elbo_neg_ave: 1.2647, test_pred_logloss: 1.2467, test_pred_accuracy: 0.5227
# Epoch [25/100], Objective: 1.2368
# Epoch [26/100], train_pred_logloss: 1.2332, train_pred_accuracy: 0.5168, elbo_neg_ave: 1.2639, test_pred_logloss: 1.2479, test_pred_accuracy: 0.5239
# Epoch [26/100], Objective: 1.2358
# Epoch [27/100], train_pred_logloss: 1.2324, train_pred_accuracy: 0.5184, elbo_neg_ave: 1.2625, test_pred_logloss: 1.2488, test_pred_accuracy: 0.5216
# Epoch [27/100], Objective: 1.2347
# Epoch [28/100], train_pred_logloss: 1.2309, train_pred_accuracy: 0.5188, elbo_neg_ave: 1.2624, test_pred_logloss: 1.2439, test_pred_accuracy: 0.5227
# Epoch [28/100], Objective: 1.2336
# Epoch [29/100], train_pred_logloss: 1.2300, train_pred_accuracy: 0.5181, elbo_neg_ave: 1.2617, test_pred_logloss: 1.2463, test_pred_accuracy: 0.5243
# Epoch [29/100], Objective: 1.2327
# Epoch [30/100], train_pred_logloss: 1.2294, train_pred_accuracy: 0.5219, elbo_neg_ave: 1.2598, test_pred_logloss: 1.2423, test_pred_accuracy: 0.5260
# Epoch [30/100], Objective: 1.2317
# Epoch [31/100], train_pred_logloss: 1.2274, train_pred_accuracy: 0.5202, elbo_neg_ave: 1.2589, test_pred_logloss: 1.2411, test_pred_accuracy: 0.5251
# Epoch [31/100], Objective: 1.2308
# Epoch [32/100], train_pred_logloss: 1.2270, train_pred_accuracy: 0.5224, elbo_neg_ave: 1.2580, test_pred_logloss: 1.2413, test_pred_accuracy: 0.5277
# Epoch [32/100], Objective: 1.2300
# Epoch [33/100], train_pred_logloss: 1.2261, train_pred_accuracy: 0.5226, elbo_neg_ave: 1.2582, test_pred_logloss: 1.2391, test_pred_accuracy: 0.5268
# Epoch [33/100], Objective: 1.2287
# Epoch [34/100], train_pred_logloss: 1.2251, train_pred_accuracy: 0.5253, elbo_neg_ave: 1.2564, test_pred_logloss: 1.2381, test_pred_accuracy: 0.5320
# Epoch [34/100], Objective: 1.2275
# Epoch [35/100], train_pred_logloss: 1.2248, train_pred_accuracy: 0.5282, elbo_neg_ave: 1.2554, test_pred_logloss: 1.2366, test_pred_accuracy: 0.5302
# Epoch [35/100], Objective: 1.2265
# Epoch [36/100], train_pred_logloss: 1.2232, train_pred_accuracy: 0.5266, elbo_neg_ave: 1.2541, test_pred_logloss: 1.2374, test_pred_accuracy: 0.5337
# Epoch [36/100], Objective: 1.2259
# Epoch [37/100], train_pred_logloss: 1.2209, train_pred_accuracy: 0.5258, elbo_neg_ave: 1.2524, test_pred_logloss: 1.2328, test_pred_accuracy: 0.5347
# Epoch [37/100], Objective: 1.2245
# Epoch [38/100], train_pred_logloss: 1.2213, train_pred_accuracy: 0.5269, elbo_neg_ave: 1.2523, test_pred_logloss: 1.2329, test_pred_accuracy: 0.5359
# Epoch [38/100], Objective: 1.2233
# Epoch [39/100], train_pred_logloss: 1.2204, train_pred_accuracy: 0.5282, elbo_neg_ave: 1.2517, test_pred_logloss: 1.2333, test_pred_accuracy: 0.5379
# Epoch [39/100], Objective: 1.2220
# Epoch [40/100], train_pred_logloss: 1.2183, train_pred_accuracy: 0.5309, elbo_neg_ave: 1.2497, test_pred_logloss: 1.2306, test_pred_accuracy: 0.5347
# Epoch [40/100], Objective: 1.2209
# Epoch [41/100], train_pred_logloss: 1.2163, train_pred_accuracy: 0.5321, elbo_neg_ave: 1.2487, test_pred_logloss: 1.2278, test_pred_accuracy: 0.5373
# Epoch [41/100], Objective: 1.2201
# Epoch [42/100], train_pred_logloss: 1.2157, train_pred_accuracy: 0.5346, elbo_neg_ave: 1.2473, test_pred_logloss: 1.2297, test_pred_accuracy: 0.5410
# Epoch [42/100], Objective: 1.2187
# Epoch [43/100], train_pred_logloss: 1.2148, train_pred_accuracy: 0.5362, elbo_neg_ave: 1.2471, test_pred_logloss: 1.2270, test_pred_accuracy: 0.5409
# Epoch [43/100], Objective: 1.2178
# Epoch [44/100], train_pred_logloss: 1.2136, train_pred_accuracy: 0.5365, elbo_neg_ave: 1.2454, test_pred_logloss: 1.2237, test_pred_accuracy: 0.5429
# Epoch [44/100], Objective: 1.2168
# Epoch [45/100], train_pred_logloss: 1.2118, train_pred_accuracy: 0.5359, elbo_neg_ave: 1.2442, test_pred_logloss: 1.2249, test_pred_accuracy: 0.5438
# Epoch [45/100], Objective: 1.2153
# Epoch [46/100], train_pred_logloss: 1.2113, train_pred_accuracy: 0.5373, elbo_neg_ave: 1.2435, test_pred_logloss: 1.2232, test_pred_accuracy: 0.5444
# Epoch [46/100], Objective: 1.2147
# Epoch [47/100], train_pred_logloss: 1.2104, train_pred_accuracy: 0.5398, elbo_neg_ave: 1.2425, test_pred_logloss: 1.2223, test_pred_accuracy: 0.5440
# Epoch [47/100], Objective: 1.2135
# Epoch [48/100], train_pred_logloss: 1.2097, train_pred_accuracy: 0.5407, elbo_neg_ave: 1.2410, test_pred_logloss: 1.2192, test_pred_accuracy: 0.5435
# Epoch [48/100], Objective: 1.2119
# Epoch [49/100], train_pred_logloss: 1.2069, train_pred_accuracy: 0.5406, elbo_neg_ave: 1.2402, test_pred_logloss: 1.2179, test_pred_accuracy: 0.5463
# Epoch [49/100], Objective: 1.2110
# Epoch [50/100], train_pred_logloss: 1.2070, train_pred_accuracy: 0.5420, elbo_neg_ave: 1.2388, test_pred_logloss: 1.2166, test_pred_accuracy: 0.5460
# Epoch [50/100], Objective: 1.2098
# Epoch [51/100], train_pred_logloss: 1.2070, train_pred_accuracy: 0.5421, elbo_neg_ave: 1.2385, test_pred_logloss: 1.2147, test_pred_accuracy: 0.5476
# Epoch [51/100], Objective: 1.2090
# Epoch [52/100], train_pred_logloss: 1.2045, train_pred_accuracy: 0.5442, elbo_neg_ave: 1.2365, test_pred_logloss: 1.2161, test_pred_accuracy: 0.5486
# Epoch [52/100], Objective: 1.2075
# Epoch [53/100], train_pred_logloss: 1.2036, train_pred_accuracy: 0.5445, elbo_neg_ave: 1.2354, test_pred_logloss: 1.2141, test_pred_accuracy: 0.5489
# Epoch [53/100], Objective: 1.2066
# Epoch [54/100], train_pred_logloss: 1.2020, train_pred_accuracy: 0.5452, elbo_neg_ave: 1.2347, test_pred_logloss: 1.2128, test_pred_accuracy: 0.5480
# Epoch [54/100], Objective: 1.2055
# Epoch [55/100], train_pred_logloss: 1.2014, train_pred_accuracy: 0.5450, elbo_neg_ave: 1.2329, test_pred_logloss: 1.2107, test_pred_accuracy: 0.5510
# Epoch [55/100], Objective: 1.2041
# Epoch [56/100], train_pred_logloss: 1.2001, train_pred_accuracy: 0.5461, elbo_neg_ave: 1.2318, test_pred_logloss: 1.2102, test_pred_accuracy: 0.5501
# Epoch [56/100], Objective: 1.2034
# Epoch [57/100], train_pred_logloss: 1.1996, train_pred_accuracy: 0.5463, elbo_neg_ave: 1.2320, test_pred_logloss: 1.2096, test_pred_accuracy: 0.5506
# Epoch [57/100], Objective: 1.2018
# Epoch [58/100], train_pred_logloss: 1.1974, train_pred_accuracy: 0.5464, elbo_neg_ave: 1.2297, test_pred_logloss: 1.2077, test_pred_accuracy: 0.5515
# Epoch [58/100], Objective: 1.2008
# Epoch [59/100], train_pred_logloss: 1.1962, train_pred_accuracy: 0.5460, elbo_neg_ave: 1.2284, test_pred_logloss: 1.2071, test_pred_accuracy: 0.5527
# Epoch [59/100], Objective: 1.2001
# Epoch [60/100], train_pred_logloss: 1.1957, train_pred_accuracy: 0.5479, elbo_neg_ave: 1.2278, test_pred_logloss: 1.2047, test_pred_accuracy: 0.5508
# Epoch [60/100], Objective: 1.1991
# Epoch [61/100], train_pred_logloss: 1.1949, train_pred_accuracy: 0.5479, elbo_neg_ave: 1.2259, test_pred_logloss: 1.2046, test_pred_accuracy: 0.5552
# Epoch [61/100], Objective: 1.1975
# Epoch [62/100], train_pred_logloss: 1.1939, train_pred_accuracy: 0.5469, elbo_neg_ave: 1.2257, test_pred_logloss: 1.2029, test_pred_accuracy: 0.5533
# Epoch [62/100], Objective: 1.1967
# Epoch [63/100], train_pred_logloss: 1.1929, train_pred_accuracy: 0.5478, elbo_neg_ave: 1.2245, test_pred_logloss: 1.2015, test_pred_accuracy: 0.5531
# Epoch [63/100], Objective: 1.1959
# Epoch [64/100], train_pred_logloss: 1.1909, train_pred_accuracy: 0.5501, elbo_neg_ave: 1.2232, test_pred_logloss: 1.1982, test_pred_accuracy: 0.5564
# Epoch [64/100], Objective: 1.1947
# Epoch [65/100], train_pred_logloss: 1.1901, train_pred_accuracy: 0.5493, elbo_neg_ave: 1.2223, test_pred_logloss: 1.1988, test_pred_accuracy: 0.5573
# Epoch [65/100], Objective: 1.1929
# Epoch [66/100], train_pred_logloss: 1.1901, train_pred_accuracy: 0.5502, elbo_neg_ave: 1.2214, test_pred_logloss: 1.1974, test_pred_accuracy: 0.5570
# Epoch [66/100], Objective: 1.1924
# Epoch [67/100], train_pred_logloss: 1.1891, train_pred_accuracy: 0.5498, elbo_neg_ave: 1.2209, test_pred_logloss: 1.1971, test_pred_accuracy: 0.5581
# Epoch [67/100], Objective: 1.1910
# Epoch [68/100], train_pred_logloss: 1.1870, train_pred_accuracy: 0.5492, elbo_neg_ave: 1.2195, test_pred_logloss: 1.1959, test_pred_accuracy: 0.5576
# Epoch [68/100], Objective: 1.1904
# Epoch [69/100], train_pred_logloss: 1.1866, train_pred_accuracy: 0.5487, elbo_neg_ave: 1.2187, test_pred_logloss: 1.1943, test_pred_accuracy: 0.5580
# Epoch [69/100], Objective: 1.1891
# Epoch [70/100], train_pred_logloss: 1.1852, train_pred_accuracy: 0.5525, elbo_neg_ave: 1.2170, test_pred_logloss: 1.1933, test_pred_accuracy: 0.5577
# Epoch [70/100], Objective: 1.1885
# Epoch [71/100], train_pred_logloss: 1.1850, train_pred_accuracy: 0.5508, elbo_neg_ave: 1.2171, test_pred_logloss: 1.1920, test_pred_accuracy: 0.5582
# Epoch [71/100], Objective: 1.1869
# Epoch [72/100], train_pred_logloss: 1.1844, train_pred_accuracy: 0.5504, elbo_neg_ave: 1.2168, test_pred_logloss: 1.1903, test_pred_accuracy: 0.5584
# Epoch [72/100], Objective: 1.1862
# Epoch [73/100], train_pred_logloss: 1.1827, train_pred_accuracy: 0.5516, elbo_neg_ave: 1.2153, test_pred_logloss: 1.1901, test_pred_accuracy: 0.5588
# Epoch [73/100], Objective: 1.1851
# Epoch [74/100], train_pred_logloss: 1.1817, train_pred_accuracy: 0.5523, elbo_neg_ave: 1.2133, test_pred_logloss: 1.1902, test_pred_accuracy: 0.5580
# Epoch [74/100], Objective: 1.1841
# Epoch [75/100], train_pred_logloss: 1.1808, train_pred_accuracy: 0.5527, elbo_neg_ave: 1.2127, test_pred_logloss: 1.1887, test_pred_accuracy: 0.5591
# Epoch [75/100], Objective: 1.1832
# Epoch [76/100], train_pred_logloss: 1.1792, train_pred_accuracy: 0.5547, elbo_neg_ave: 1.2119, test_pred_logloss: 1.1881, test_pred_accuracy: 0.5589
# Epoch [76/100], Objective: 1.1822
# Epoch [77/100], train_pred_logloss: 1.1786, train_pred_accuracy: 0.5538, elbo_neg_ave: 1.2107, test_pred_logloss: 1.1858, test_pred_accuracy: 0.5621
# Epoch [77/100], Objective: 1.1815
# Epoch [78/100], train_pred_logloss: 1.1777, train_pred_accuracy: 0.5554, elbo_neg_ave: 1.2099, test_pred_logloss: 1.1842, test_pred_accuracy: 0.5614
# Epoch [78/100], Objective: 1.1804
# Epoch [79/100], train_pred_logloss: 1.1773, train_pred_accuracy: 0.5545, elbo_neg_ave: 1.2084, test_pred_logloss: 1.1843, test_pred_accuracy: 0.5609
# Epoch [79/100], Objective: 1.1789
# Epoch [80/100], train_pred_logloss: 1.1747, train_pred_accuracy: 0.5560, elbo_neg_ave: 1.2081, test_pred_logloss: 1.1798, test_pred_accuracy: 0.5589
# Epoch [80/100], Objective: 1.1782
# Epoch [81/100], train_pred_logloss: 1.1736, train_pred_accuracy: 0.5550, elbo_neg_ave: 1.2063, test_pred_logloss: 1.1829, test_pred_accuracy: 0.5618
# Epoch [81/100], Objective: 1.1774
# Epoch [82/100], train_pred_logloss: 1.1744, train_pred_accuracy: 0.5559, elbo_neg_ave: 1.2065, test_pred_logloss: 1.1824, test_pred_accuracy: 0.5598
# Epoch [82/100], Objective: 1.1765
# Epoch [83/100], train_pred_logloss: 1.1717, train_pred_accuracy: 0.5568, elbo_neg_ave: 1.2045, test_pred_logloss: 1.1804, test_pred_accuracy: 0.5611
# Epoch [83/100], Objective: 1.1756
# Epoch [84/100], train_pred_logloss: 1.1719, train_pred_accuracy: 0.5569, elbo_neg_ave: 1.2041, test_pred_logloss: 1.1800, test_pred_accuracy: 0.5630
# Epoch [84/100], Objective: 1.1749
# Epoch [85/100], train_pred_logloss: 1.1708, train_pred_accuracy: 0.5572, elbo_neg_ave: 1.2027, test_pred_logloss: 1.1757, test_pred_accuracy: 0.5616
# Epoch [85/100], Objective: 1.1735
# Epoch [86/100], train_pred_logloss: 1.1698, train_pred_accuracy: 0.5584, elbo_neg_ave: 1.2020, test_pred_logloss: 1.1780, test_pred_accuracy: 0.5606
# Epoch [86/100], Objective: 1.1727
# Epoch [87/100], train_pred_logloss: 1.1690, train_pred_accuracy: 0.5579, elbo_neg_ave: 1.2011, test_pred_logloss: 1.1746, test_pred_accuracy: 0.5628
# Epoch [87/100], Objective: 1.1716
# Epoch [88/100], train_pred_logloss: 1.1685, train_pred_accuracy: 0.5576, elbo_neg_ave: 1.2002, test_pred_logloss: 1.1769, test_pred_accuracy: 0.5633
# Epoch [88/100], Objective: 1.1704
# Epoch [89/100], train_pred_logloss: 1.1671, train_pred_accuracy: 0.5591, elbo_neg_ave: 1.1994, test_pred_logloss: 1.1745, test_pred_accuracy: 0.5654
# Epoch [89/100], Objective: 1.1692
# Epoch [90/100], train_pred_logloss: 1.1662, train_pred_accuracy: 0.5605, elbo_neg_ave: 1.1987, test_pred_logloss: 1.1711, test_pred_accuracy: 0.5647
# Epoch [90/100], Objective: 1.1689
# Epoch [91/100], train_pred_logloss: 1.1650, train_pred_accuracy: 0.5585, elbo_neg_ave: 1.1974, test_pred_logloss: 1.1732, test_pred_accuracy: 0.5646
# Epoch [91/100], Objective: 1.1680
# Epoch [92/100], train_pred_logloss: 1.1643, train_pred_accuracy: 0.5603, elbo_neg_ave: 1.1967, test_pred_logloss: 1.1726, test_pred_accuracy: 0.5648
# Epoch [92/100], Objective: 1.1674
# Epoch [93/100], train_pred_logloss: 1.1629, train_pred_accuracy: 0.5613, elbo_neg_ave: 1.1951, test_pred_logloss: 1.1714, test_pred_accuracy: 0.5650
# Epoch [93/100], Objective: 1.1658
# Epoch [94/100], train_pred_logloss: 1.1619, train_pred_accuracy: 0.5618, elbo_neg_ave: 1.1945, test_pred_logloss: 1.1699, test_pred_accuracy: 0.5665
# Epoch [94/100], Objective: 1.1652
# Epoch [95/100], train_pred_logloss: 1.1601, train_pred_accuracy: 0.5615, elbo_neg_ave: 1.1935, test_pred_logloss: 1.1682, test_pred_accuracy: 0.5659
# Epoch [95/100], Objective: 1.1640
# Epoch [96/100], train_pred_logloss: 1.1614, train_pred_accuracy: 0.5626, elbo_neg_ave: 1.1928, test_pred_logloss: 1.1659, test_pred_accuracy: 0.5657
# Epoch [96/100], Objective: 1.1634
# Epoch [97/100], train_pred_logloss: 1.1593, train_pred_accuracy: 0.5630, elbo_neg_ave: 1.1916, test_pred_logloss: 1.1671, test_pred_accuracy: 0.5671
# Epoch [97/100], Objective: 1.1619
# Epoch [98/100], train_pred_logloss: 1.1587, train_pred_accuracy: 0.5628, elbo_neg_ave: 1.1903, test_pred_logloss: 1.1645, test_pred_accuracy: 0.5691
# Epoch [98/100], Objective: 1.1615
# Epoch [99/100], train_pred_logloss: 1.1573, train_pred_accuracy: 0.5647, elbo_neg_ave: 1.1897, test_pred_logloss: 1.1643, test_pred_accuracy: 0.5680
# Epoch [99/100], Objective: 1.1603
# Epoch [100/100], train_pred_logloss: 1.1576, train_pred_accuracy: 0.5643, elbo_neg_ave: 1.1889, test_pred_logloss: 1.1647, test_pred_accuracy: 0.5698
# Epoch [100/100], Objective: 1.1594
# Epoch [1/100], train_pred_logloss: 1.1560, train_pred_accuracy: 0.5636, elbo_neg_ave: 1.1881, test_pred_logloss: 1.1624, test_pred_accuracy: 0.5697
# Epoch [1/100], Objective: 1.1588
# Epoch [2/100], train_pred_logloss: 1.1556, train_pred_accuracy: 0.5644, elbo_neg_ave: 1.1876, test_pred_logloss: 1.1619, test_pred_accuracy: 0.5717
# Epoch [2/100], Objective: 1.1578
# Epoch [3/100], train_pred_logloss: 1.1536, train_pred_accuracy: 0.5633, elbo_neg_ave: 1.1860, test_pred_logloss: 1.1610, test_pred_accuracy: 0.5715
# Epoch [3/100], Objective: 1.1567
# Epoch [4/100], train_pred_logloss: 1.1527, train_pred_accuracy: 0.5665, elbo_neg_ave: 1.1853, test_pred_logloss: 1.1591, test_pred_accuracy: 0.5706
# Epoch [4/100], Objective: 1.1562
# Epoch [5/100], train_pred_logloss: 1.1525, train_pred_accuracy: 0.5667, elbo_neg_ave: 1.1838, test_pred_logloss: 1.1593, test_pred_accuracy: 0.5711
# Epoch [5/100], Objective: 1.1552
# Epoch [6/100], train_pred_logloss: 1.1523, train_pred_accuracy: 0.5662, elbo_neg_ave: 1.1840, test_pred_logloss: 1.1590, test_pred_accuracy: 0.5718
# Epoch [6/100], Objective: 1.1540
# Epoch [7/100], train_pred_logloss: 1.1508, train_pred_accuracy: 0.5672, elbo_neg_ave: 1.1824, test_pred_logloss: 1.1579, test_pred_accuracy: 0.5750
# Epoch [7/100], Objective: 1.1532
# Epoch [8/100], train_pred_logloss: 1.1502, train_pred_accuracy: 0.5680, elbo_neg_ave: 1.1816, test_pred_logloss: 1.1583, test_pred_accuracy: 0.5715
# Epoch [8/100], Objective: 1.1524
# Epoch [9/100], train_pred_logloss: 1.1482, train_pred_accuracy: 0.5666, elbo_neg_ave: 1.1808, test_pred_logloss: 1.1579, test_pred_accuracy: 0.5719
# Epoch [9/100], Objective: 1.1513
# Epoch [10/100], train_pred_logloss: 1.1478, train_pred_accuracy: 0.5674, elbo_neg_ave: 1.1799, test_pred_logloss: 1.1565, test_pred_accuracy: 0.5728
# Epoch [10/100], Objective: 1.1509
# Epoch [11/100], train_pred_logloss: 1.1476, train_pred_accuracy: 0.5691, elbo_neg_ave: 1.1791, test_pred_logloss: 1.1552, test_pred_accuracy: 0.5749
# Epoch [11/100], Objective: 1.1500
# Epoch [12/100], train_pred_logloss: 1.1472, train_pred_accuracy: 0.5695, elbo_neg_ave: 1.1789, test_pred_logloss: 1.1555, test_pred_accuracy: 0.5733
# Epoch [12/100], Objective: 1.1488
# Epoch [13/100], train_pred_logloss: 1.1448, train_pred_accuracy: 0.5690, elbo_neg_ave: 1.1778, test_pred_logloss: 1.1529, test_pred_accuracy: 0.5727
# Epoch [13/100], Objective: 1.1478
# Epoch [14/100], train_pred_logloss: 1.1443, train_pred_accuracy: 0.5698, elbo_neg_ave: 1.1765, test_pred_logloss: 1.1533, test_pred_accuracy: 0.5763
# Epoch [14/100], Objective: 1.1478
# Epoch [15/100], train_pred_logloss: 1.1432, train_pred_accuracy: 0.5699, elbo_neg_ave: 1.1759, test_pred_logloss: 1.1530, test_pred_accuracy: 0.5766
# Epoch [15/100], Objective: 1.1463
# Epoch [16/100], train_pred_logloss: 1.1426, train_pred_accuracy: 0.5703, elbo_neg_ave: 1.1745, test_pred_logloss: 1.1510, test_pred_accuracy: 0.5774
# Epoch [16/100], Objective: 1.1463
# Epoch [17/100], train_pred_logloss: 1.1427, train_pred_accuracy: 0.5720, elbo_neg_ave: 1.1744, test_pred_logloss: 1.1489, test_pred_accuracy: 0.5774
# Epoch [17/100], Objective: 1.1454
# Epoch [18/100], train_pred_logloss: 1.1408, train_pred_accuracy: 0.5698, elbo_neg_ave: 1.1740, test_pred_logloss: 1.1513, test_pred_accuracy: 0.5784
# Epoch [18/100], Objective: 1.1442
# Epoch [19/100], train_pred_logloss: 1.1402, train_pred_accuracy: 0.5714, elbo_neg_ave: 1.1725, test_pred_logloss: 1.1474, test_pred_accuracy: 0.5781
# Epoch [19/100], Objective: 1.1435
# Epoch [20/100], train_pred_logloss: 1.1401, train_pred_accuracy: 0.5718, elbo_neg_ave: 1.1727, test_pred_logloss: 1.1478, test_pred_accuracy: 0.5764
# Epoch [20/100], Objective: 1.1429
# Epoch [21/100], train_pred_logloss: 1.1391, train_pred_accuracy: 0.5727, elbo_neg_ave: 1.1703, test_pred_logloss: 1.1469, test_pred_accuracy: 0.5776
# Epoch [21/100], Objective: 1.1415
# Epoch [22/100], train_pred_logloss: 1.1390, train_pred_accuracy: 0.5739, elbo_neg_ave: 1.1710, test_pred_logloss: 1.1468, test_pred_accuracy: 0.5813
# Epoch [22/100], Objective: 1.1416
# Epoch [23/100], train_pred_logloss: 1.1367, train_pred_accuracy: 0.5724, elbo_neg_ave: 1.1685, test_pred_logloss: 1.1464, test_pred_accuracy: 0.5807
# Epoch [23/100], Objective: 1.1406
# Epoch [24/100], train_pred_logloss: 1.1370, train_pred_accuracy: 0.5735, elbo_neg_ave: 1.1691, test_pred_logloss: 1.1451, test_pred_accuracy: 0.5808
# Epoch [24/100], Objective: 1.1400
# Epoch [25/100], train_pred_logloss: 1.1352, train_pred_accuracy: 0.5738, elbo_neg_ave: 1.1674, test_pred_logloss: 1.1425, test_pred_accuracy: 0.5819
# Epoch [25/100], Objective: 1.1387
# Epoch [26/100], train_pred_logloss: 1.1355, train_pred_accuracy: 0.5760, elbo_neg_ave: 1.1672, test_pred_logloss: 1.1420, test_pred_accuracy: 0.5818
# Epoch [26/100], Objective: 1.1380
# Epoch [27/100], train_pred_logloss: 1.1342, train_pred_accuracy: 0.5758, elbo_neg_ave: 1.1660, test_pred_logloss: 1.1445, test_pred_accuracy: 0.5824
# Epoch [27/100], Objective: 1.1374
# Epoch [28/100], train_pred_logloss: 1.1342, train_pred_accuracy: 0.5753, elbo_neg_ave: 1.1664, test_pred_logloss: 1.1409, test_pred_accuracy: 0.5820
# Epoch [28/100], Objective: 1.1361
# Epoch [29/100], train_pred_logloss: 1.1332, train_pred_accuracy: 0.5763, elbo_neg_ave: 1.1654, test_pred_logloss: 1.1440, test_pred_accuracy: 0.5846
# Epoch [29/100], Objective: 1.1354
# Epoch [30/100], train_pred_logloss: 1.1324, train_pred_accuracy: 0.5762, elbo_neg_ave: 1.1640, test_pred_logloss: 1.1403, test_pred_accuracy: 0.5849
# Epoch [30/100], Objective: 1.1349
# Epoch [31/100], train_pred_logloss: 1.1305, train_pred_accuracy: 0.5763, elbo_neg_ave: 1.1637, test_pred_logloss: 1.1391, test_pred_accuracy: 0.5846
# Epoch [31/100], Objective: 1.1341
# Epoch [32/100], train_pred_logloss: 1.1304, train_pred_accuracy: 0.5769, elbo_neg_ave: 1.1628, test_pred_logloss: 1.1404, test_pred_accuracy: 0.5872
# Epoch [32/100], Objective: 1.1337
# Epoch [33/100], train_pred_logloss: 1.1301, train_pred_accuracy: 0.5790, elbo_neg_ave: 1.1635, test_pred_logloss: 1.1373, test_pred_accuracy: 0.5854
# Epoch [33/100], Objective: 1.1325
# Epoch [34/100], train_pred_logloss: 1.1295, train_pred_accuracy: 0.5804, elbo_neg_ave: 1.1612, test_pred_logloss: 1.1388, test_pred_accuracy: 0.5877
# Epoch [34/100], Objective: 1.1318
# Epoch [35/100], train_pred_logloss: 1.1290, train_pred_accuracy: 0.5807, elbo_neg_ave: 1.1612, test_pred_logloss: 1.1375, test_pred_accuracy: 0.5869
# Epoch [35/100], Objective: 1.1311
# Epoch [36/100], train_pred_logloss: 1.1288, train_pred_accuracy: 0.5813, elbo_neg_ave: 1.1601, test_pred_logloss: 1.1362, test_pred_accuracy: 0.5910
# Epoch [36/100], Objective: 1.1306
# Epoch [37/100], train_pred_logloss: 1.1263, train_pred_accuracy: 0.5808, elbo_neg_ave: 1.1586, test_pred_logloss: 1.1352, test_pred_accuracy: 0.5895
# Epoch [37/100], Objective: 1.1298
# Epoch [38/100], train_pred_logloss: 1.1271, train_pred_accuracy: 0.5806, elbo_neg_ave: 1.1584, test_pred_logloss: 1.1344, test_pred_accuracy: 0.5916
# Epoch [38/100], Objective: 1.1289
# Epoch [39/100], train_pred_logloss: 1.1266, train_pred_accuracy: 0.5825, elbo_neg_ave: 1.1580, test_pred_logloss: 1.1353, test_pred_accuracy: 0.5940
# Epoch [39/100], Objective: 1.1287
# Epoch [40/100], train_pred_logloss: 1.1244, train_pred_accuracy: 0.5848, elbo_neg_ave: 1.1562, test_pred_logloss: 1.1341, test_pred_accuracy: 0.5933
# Epoch [40/100], Objective: 1.1272
# Epoch [41/100], train_pred_logloss: 1.1242, train_pred_accuracy: 0.5854, elbo_neg_ave: 1.1566, test_pred_logloss: 1.1312, test_pred_accuracy: 0.5960
# Epoch [41/100], Objective: 1.1268
# Epoch [42/100], train_pred_logloss: 1.1230, train_pred_accuracy: 0.5879, elbo_neg_ave: 1.1545, test_pred_logloss: 1.1329, test_pred_accuracy: 0.5956
# Epoch [42/100], Objective: 1.1258
# Epoch [43/100], train_pred_logloss: 1.1225, train_pred_accuracy: 0.5888, elbo_neg_ave: 1.1547, test_pred_logloss: 1.1326, test_pred_accuracy: 0.5969
# Epoch [43/100], Objective: 1.1253
# Epoch [44/100], train_pred_logloss: 1.1219, train_pred_accuracy: 0.5878, elbo_neg_ave: 1.1540, test_pred_logloss: 1.1283, test_pred_accuracy: 0.5956
# Epoch [44/100], Objective: 1.1244
# Epoch [45/100], train_pred_logloss: 1.1200, train_pred_accuracy: 0.5900, elbo_neg_ave: 1.1527, test_pred_logloss: 1.1308, test_pred_accuracy: 0.5981
# Epoch [45/100], Objective: 1.1238
# Epoch [46/100], train_pred_logloss: 1.1201, train_pred_accuracy: 0.5905, elbo_neg_ave: 1.1529, test_pred_logloss: 1.1283, test_pred_accuracy: 0.5999
# Epoch [46/100], Objective: 1.1235
# Epoch [47/100], train_pred_logloss: 1.1201, train_pred_accuracy: 0.5892, elbo_neg_ave: 1.1524, test_pred_logloss: 1.1290, test_pred_accuracy: 0.5996
# Epoch [47/100], Objective: 1.1226
# Epoch [48/100], train_pred_logloss: 1.1191, train_pred_accuracy: 0.5894, elbo_neg_ave: 1.1511, test_pred_logloss: 1.1282, test_pred_accuracy: 0.5988
# Epoch [48/100], Objective: 1.1213
# Epoch [49/100], train_pred_logloss: 1.1168, train_pred_accuracy: 0.5918, elbo_neg_ave: 1.1499, test_pred_logloss: 1.1259, test_pred_accuracy: 0.6007
# Epoch [49/100], Objective: 1.1209
# Epoch [50/100], train_pred_logloss: 1.1174, train_pred_accuracy: 0.5919, elbo_neg_ave: 1.1495, test_pred_logloss: 1.1257, test_pred_accuracy: 0.5972
# Epoch [50/100], Objective: 1.1197
# ...
# Epoch [13/100], Objective: 0.9787
# Epoch [14/100], train_pred_logloss: 0.9744, train_pred_accuracy: 0.6900, elbo_neg_ave: 1.0090, test_pred_logloss: 0.9822, test_pred_accuracy: 0.6903
# Epoch [14/100], Objective: 0.9786
# Epoch [15/100], train_pred_logloss: 0.9734, train_pred_accuracy: 0.6901, elbo_neg_ave: 1.0084, test_pred_logloss: 0.9820, test_pred_accuracy: 0.6915
# Epoch [15/100], Objective: 0.9774
# Epoch [16/100], train_pred_logloss: 0.9737, train_pred_accuracy: 0.6891, elbo_neg_ave: 1.0074, test_pred_logloss: 0.9804, test_pred_accuracy: 0.6920
# Epoch [16/100], Objective: 0.9772
# Epoch [17/100], train_pred_logloss: 0.9736, train_pred_accuracy: 0.6908, elbo_neg_ave: 1.0077, test_pred_logloss: 0.9803, test_pred_accuracy: 0.6927
# Epoch [17/100], Objective: 0.9768
# Epoch [18/100], train_pred_logloss: 0.9721, train_pred_accuracy: 0.6891, elbo_neg_ave: 1.0071, test_pred_logloss: 0.9808, test_pred_accuracy: 0.6927
# Epoch [18/100], Objective: 0.9754
# Epoch [19/100], train_pred_logloss: 0.9715, train_pred_accuracy: 0.6889, elbo_neg_ave: 1.0063, test_pred_logloss: 0.9790, test_pred_accuracy: 0.6916
# Epoch [19/100], Objective: 0.9750
# Epoch [20/100], train_pred_logloss: 0.9720, train_pred_accuracy: 0.6904, elbo_neg_ave: 1.0065, test_pred_logloss: 0.9790, test_pred_accuracy: 0.6913
# Epoch [20/100], Objective: 0.9747
# Epoch [21/100], train_pred_logloss: 0.9701, train_pred_accuracy: 0.6892, elbo_neg_ave: 1.0041, test_pred_logloss: 0.9780, test_pred_accuracy: 0.6924
# Epoch [21/100], Objective: 0.9734
# Epoch [22/100], train_pred_logloss: 0.9705, train_pred_accuracy: 0.6908, elbo_neg_ave: 1.0054, test_pred_logloss: 0.9773, test_pred_accuracy: 0.6931
# Epoch [22/100], Objective: 0.9736
# Epoch [23/100], train_pred_logloss: 0.9686, train_pred_accuracy: 0.6909, elbo_neg_ave: 1.0024, test_pred_logloss: 0.9766, test_pred_accuracy: 0.6914
# Epoch [23/100], Objective: 0.9731
# Epoch [24/100], train_pred_logloss: 0.9695, train_pred_accuracy: 0.6896, elbo_neg_ave: 1.0038, test_pred_logloss: 0.9770, test_pred_accuracy: 0.6943
# Epoch [24/100], Objective: 0.9726
# Epoch [25/100], train_pred_logloss: 0.9677, train_pred_accuracy: 0.6894, elbo_neg_ave: 1.0023, test_pred_logloss: 0.9756, test_pred_accuracy: 0.6940
# Epoch [25/100], Objective: 0.9719
# Epoch [26/100], train_pred_logloss: 0.9685, train_pred_accuracy: 0.6915, elbo_neg_ave: 1.0025, test_pred_logloss: 0.9752, test_pred_accuracy: 0.6916
# Epoch [26/100], Objective: 0.9709
# Epoch [27/100], train_pred_logloss: 0.9673, train_pred_accuracy: 0.6910, elbo_neg_ave: 1.0013, test_pred_logloss: 0.9768, test_pred_accuracy: 0.6937
# Epoch [27/100], Objective: 0.9707
# Epoch [28/100], train_pred_logloss: 0.9672, train_pred_accuracy: 0.6916, elbo_neg_ave: 1.0022, test_pred_logloss: 0.9733, test_pred_accuracy: 0.6935
# Epoch [28/100], Objective: 0.9698
# Epoch [29/100], train_pred_logloss: 0.9669, train_pred_accuracy: 0.6902, elbo_neg_ave: 1.0014, test_pred_logloss: 0.9749, test_pred_accuracy: 0.6908
# Epoch [29/100], Objective: 0.9693
# Epoch [30/100], train_pred_logloss: 0.9660, train_pred_accuracy: 0.6909, elbo_neg_ave: 1.0006, test_pred_logloss: 0.9723, test_pred_accuracy: 0.6947
# Epoch [30/100], Objective: 0.9689
# Epoch [31/100], train_pred_logloss: 0.9642, train_pred_accuracy: 0.6922, elbo_neg_ave: 1.0007, test_pred_logloss: 0.9711, test_pred_accuracy: 0.6932
# Epoch [31/100], Objective: 0.9685
# Epoch [32/100], train_pred_logloss: 0.9652, train_pred_accuracy: 0.6911, elbo_neg_ave: 0.9998, test_pred_logloss: 0.9730, test_pred_accuracy: 0.6931
# Epoch [32/100], Objective: 0.9683
# Epoch [33/100], train_pred_logloss: 0.9647, train_pred_accuracy: 0.6906, elbo_neg_ave: 1.0008, test_pred_logloss: 0.9708, test_pred_accuracy: 0.6928
# Epoch [33/100], Objective: 0.9672
# Epoch [34/100], train_pred_logloss: 0.9650, train_pred_accuracy: 0.6900, elbo_neg_ave: 0.9988, test_pred_logloss: 0.9709, test_pred_accuracy: 0.6934
# Epoch [34/100], Objective: 0.9671
# Epoch [35/100], train_pred_logloss: 0.9643, train_pred_accuracy: 0.6908, elbo_neg_ave: 0.9992, test_pred_logloss: 0.9704, test_pred_accuracy: 0.6937
# Epoch [35/100], Objective: 0.9668
# Epoch [36/100], train_pred_logloss: 0.9649, train_pred_accuracy: 0.6918, elbo_neg_ave: 0.9989, test_pred_logloss: 0.9691, test_pred_accuracy: 0.6942
# Epoch [36/100], Objective: 0.9660
# Epoch [37/100], train_pred_logloss: 0.9622, train_pred_accuracy: 0.6923, elbo_neg_ave: 0.9968, test_pred_logloss: 0.9701, test_pred_accuracy: 0.6940
# Epoch [37/100], Objective: 0.9662
# Epoch [38/100], train_pred_logloss: 0.9634, train_pred_accuracy: 0.6919, elbo_neg_ave: 0.9970, test_pred_logloss: 0.9677, test_pred_accuracy: 0.6944
# Epoch [38/100], Objective: 0.9655
# Epoch [39/100], train_pred_logloss: 0.9630, train_pred_accuracy: 0.6915, elbo_neg_ave: 0.9972, test_pred_logloss: 0.9697, test_pred_accuracy: 0.6947
# Epoch [39/100], Objective: 0.9654
# Epoch [40/100], train_pred_logloss: 0.9615, train_pred_accuracy: 0.6916, elbo_neg_ave: 0.9958, test_pred_logloss: 0.9699, test_pred_accuracy: 0.6938
# Epoch [40/100], Objective: 0.9647
# Epoch [41/100], train_pred_logloss: 0.9617, train_pred_accuracy: 0.6922, elbo_neg_ave: 0.9970, test_pred_logloss: 0.9676, test_pred_accuracy: 0.6951
# Epoch [41/100], Objective: 0.9643
# Epoch [42/100], train_pred_logloss: 0.9608, train_pred_accuracy: 0.6923, elbo_neg_ave: 0.9948, test_pred_logloss: 0.9679, test_pred_accuracy: 0.6964
# Epoch [42/100], Objective: 0.9637
# Epoch [43/100], train_pred_logloss: 0.9601, train_pred_accuracy: 0.6917, elbo_neg_ave: 0.9953, test_pred_logloss: 0.9673, test_pred_accuracy: 0.6952
# Epoch [43/100], Objective: 0.9636
# Epoch [44/100], train_pred_logloss: 0.9602, train_pred_accuracy: 0.6906, elbo_neg_ave: 0.9951, test_pred_logloss: 0.9650, test_pred_accuracy: 0.6943
# Epoch [44/100], Objective: 0.9631
# Epoch [45/100], train_pred_logloss: 0.9587, train_pred_accuracy: 0.6918, elbo_neg_ave: 0.9938, test_pred_logloss: 0.9675, test_pred_accuracy: 0.6972
# Epoch [45/100], Objective: 0.9626
# Epoch [46/100], train_pred_logloss: 0.9599, train_pred_accuracy: 0.6937, elbo_neg_ave: 0.9952, test_pred_logloss: 0.9648, test_pred_accuracy: 0.6945
# Epoch [46/100], Objective: 0.9629
# Epoch [47/100], train_pred_logloss: 0.9593, train_pred_accuracy: 0.6928, elbo_neg_ave: 0.9943, test_pred_logloss: 0.9660, test_pred_accuracy: 0.6963
# Epoch [47/100], Objective: 0.9629
# Epoch [48/100], train_pred_logloss: 0.9594, train_pred_accuracy: 0.6907, elbo_neg_ave: 0.9943, test_pred_logloss: 0.9672, test_pred_accuracy: 0.6962
# Epoch [48/100], Objective: 0.9616
# Epoch [49/100], train_pred_logloss: 0.9583, train_pred_accuracy: 0.6931, elbo_neg_ave: 0.9928, test_pred_logloss: 0.9646, test_pred_accuracy: 0.6969
# Epoch [49/100], Objective: 0.9614
# Epoch [50/100], train_pred_logloss: 0.9587, train_pred_accuracy: 0.6925, elbo_neg_ave: 0.9931, test_pred_logloss: 0.9643, test_pred_accuracy: 0.6928
# Epoch [50/100], Objective: 0.9611
# Epoch [51/100], train_pred_logloss: 0.9584, train_pred_accuracy: 0.6920, elbo_neg_ave: 0.9934, test_pred_logloss: 0.9649, test_pred_accuracy: 0.6973
# Epoch [51/100], Objective: 0.9608
# Epoch [52/100], train_pred_logloss: 0.9572, train_pred_accuracy: 0.6928, elbo_neg_ave: 0.9922, test_pred_logloss: 0.9654, test_pred_accuracy: 0.6952
# Epoch [52/100], Objective: 0.9598
# Epoch [53/100], train_pred_logloss: 0.9572, train_pred_accuracy: 0.6934, elbo_neg_ave: 0.9919, test_pred_logloss: 0.9628, test_pred_accuracy: 0.6968
# Epoch [53/100], Objective: 0.9603
# Epoch [54/100], train_pred_logloss: 0.9569, train_pred_accuracy: 0.6930, elbo_neg_ave: 0.9926, test_pred_logloss: 0.9643, test_pred_accuracy: 0.6957
# Epoch [54/100], Objective: 0.9599
# Epoch [55/100], train_pred_logloss: 0.9568, train_pred_accuracy: 0.6935, elbo_neg_ave: 0.9911, test_pred_logloss: 0.9633, test_pred_accuracy: 0.6980
# Epoch [55/100], Objective: 0.9592
# Epoch [56/100], train_pred_logloss: 0.9562, train_pred_accuracy: 0.6938, elbo_neg_ave: 0.9906, test_pred_logloss: 0.9617, test_pred_accuracy: 0.6974
# Epoch [56/100], Objective: 0.9596
# Epoch [57/100], train_pred_logloss: 0.9559, train_pred_accuracy: 0.6938, elbo_neg_ave: 0.9916, test_pred_logloss: 0.9638, test_pred_accuracy: 0.6970
# Epoch [57/100], Objective: 0.9584
# Epoch [58/100], train_pred_logloss: 0.9555, train_pred_accuracy: 0.6948, elbo_neg_ave: 0.9898, test_pred_logloss: 0.9617, test_pred_accuracy: 0.6967
# Epoch [58/100], Objective: 0.9584
# Epoch [59/100], train_pred_logloss: 0.9548, train_pred_accuracy: 0.6936, elbo_neg_ave: 0.9894, test_pred_logloss: 0.9631, test_pred_accuracy: 0.6951
# Epoch [59/100], Objective: 0.9581
# Epoch [60/100], train_pred_logloss: 0.9549, train_pred_accuracy: 0.6924, elbo_neg_ave: 0.9904, test_pred_logloss: 0.9605, test_pred_accuracy: 0.6955
# Epoch [60/100], Objective: 0.9579
# Epoch [61/100], train_pred_logloss: 0.9547, train_pred_accuracy: 0.6950, elbo_neg_ave: 0.9893, test_pred_logloss: 0.9615, test_pred_accuracy: 0.6951
# Epoch [61/100], Objective: 0.9574
# Epoch [62/100], train_pred_logloss: 0.9552, train_pred_accuracy: 0.6946, elbo_neg_ave: 0.9895, test_pred_logloss: 0.9606, test_pred_accuracy: 0.6964
# Epoch [62/100], Objective: 0.9573
# Epoch [63/100], train_pred_logloss: 0.9545, train_pred_accuracy: 0.6958, elbo_neg_ave: 0.9888, test_pred_logloss: 0.9593, test_pred_accuracy: 0.6968
# Epoch [63/100], Objective: 0.9573
# Epoch [64/100], train_pred_logloss: 0.9540, train_pred_accuracy: 0.6945, elbo_neg_ave: 0.9885, test_pred_logloss: 0.9591, test_pred_accuracy: 0.6956
# Epoch [64/100], Objective: 0.9569
# Epoch [65/100], train_pred_logloss: 0.9538, train_pred_accuracy: 0.6931, elbo_neg_ave: 0.9879, test_pred_logloss: 0.9607, test_pred_accuracy: 0.6979
# Epoch [65/100], Objective: 0.9565
# Epoch [66/100], train_pred_logloss: 0.9541, train_pred_accuracy: 0.6944, elbo_neg_ave: 0.9879, test_pred_logloss: 0.9582, test_pred_accuracy: 0.6970
# Epoch [66/100], Objective: 0.9566
# Epoch [67/100], train_pred_logloss: 0.9535, train_pred_accuracy: 0.6935, elbo_neg_ave: 0.9884, test_pred_logloss: 0.9603, test_pred_accuracy: 0.6991
# Epoch [67/100], Objective: 0.9556
# Epoch [68/100], train_pred_logloss: 0.9525, train_pred_accuracy: 0.6952, elbo_neg_ave: 0.9878, test_pred_logloss: 0.9595, test_pred_accuracy: 0.6954
# Epoch [68/100], Objective: 0.9555
# Epoch [69/100], train_pred_logloss: 0.9524, train_pred_accuracy: 0.6943, elbo_neg_ave: 0.9876, test_pred_logloss: 0.9609, test_pred_accuracy: 0.6963
# Epoch [69/100], Objective: 0.9554
# Epoch [70/100], train_pred_logloss: 0.9517, train_pred_accuracy: 0.6965, elbo_neg_ave: 0.9865, test_pred_logloss: 0.9591, test_pred_accuracy: 0.6970
# Epoch [70/100], Objective: 0.9551
# Epoch [71/100], train_pred_logloss: 0.9522, train_pred_accuracy: 0.6924, elbo_neg_ave: 0.9880, test_pred_logloss: 0.9574, test_pred_accuracy: 0.6965
# Epoch [71/100], Objective: 0.9549
# Epoch [72/100], train_pred_logloss: 0.9520, train_pred_accuracy: 0.6935, elbo_neg_ave: 0.9883, test_pred_logloss: 0.9580, test_pred_accuracy: 0.6957
# Epoch [72/100], Objective: 0.9547
# Epoch [73/100], train_pred_logloss: 0.9520, train_pred_accuracy: 0.6932, elbo_neg_ave: 0.9870, test_pred_logloss: 0.9571, test_pred_accuracy: 0.6965
# Epoch [73/100], Objective: 0.9547
# Epoch [74/100], train_pred_logloss: 0.9510, train_pred_accuracy: 0.6938, elbo_neg_ave: 0.9856, test_pred_logloss: 0.9553, test_pred_accuracy: 0.6975
# Epoch [74/100], Objective: 0.9542
# Epoch [75/100], train_pred_logloss: 0.9509, train_pred_accuracy: 0.6946, elbo_neg_ave: 0.9861, test_pred_logloss: 0.9575, test_pred_accuracy: 0.6978
# Epoch [75/100], Objective: 0.9540
# Epoch [76/100], train_pred_logloss: 0.9518, train_pred_accuracy: 0.6956, elbo_neg_ave: 0.9870, test_pred_logloss: 0.9569, test_pred_accuracy: 0.6968
# Epoch [76/100], Objective: 0.9535
# Epoch [77/100], train_pred_logloss: 0.9501, train_pred_accuracy: 0.6954, elbo_neg_ave: 0.9868, test_pred_logloss: 0.9557, test_pred_accuracy: 0.6988
# Epoch [77/100], Objective: 0.9534
# Epoch [78/100], train_pred_logloss: 0.9506, train_pred_accuracy: 0.6952, elbo_neg_ave: 0.9862, test_pred_logloss: 0.9555, test_pred_accuracy: 0.6984
# Epoch [78/100], Objective: 0.9532
# Epoch [79/100], train_pred_logloss: 0.9502, train_pred_accuracy: 0.6948, elbo_neg_ave: 0.9851, test_pred_logloss: 0.9582, test_pred_accuracy: 0.6987
# Epoch [79/100], Objective: 0.9529
# Epoch [80/100], train_pred_logloss: 0.9491, train_pred_accuracy: 0.6957, elbo_neg_ave: 0.9852, test_pred_logloss: 0.9548, test_pred_accuracy: 0.6973
# Epoch [80/100], Objective: 0.9528
# Epoch [81/100], train_pred_logloss: 0.9489, train_pred_accuracy: 0.6941, elbo_neg_ave: 0.9846, test_pred_logloss: 0.9561, test_pred_accuracy: 0.6973
# Epoch [81/100], Objective: 0.9527
# Epoch [82/100], train_pred_logloss: 0.9506, train_pred_accuracy: 0.6953, elbo_neg_ave: 0.9855, test_pred_logloss: 0.9563, test_pred_accuracy: 0.6985
# Epoch [82/100], Objective: 0.9524
# Epoch [83/100], train_pred_logloss: 0.9491, train_pred_accuracy: 0.6956, elbo_neg_ave: 0.9848, test_pred_logloss: 0.9545, test_pred_accuracy: 0.6987
# Epoch [83/100], Objective: 0.9519
# Epoch [84/100], train_pred_logloss: 0.9492, train_pred_accuracy: 0.6958, elbo_neg_ave: 0.9843, test_pred_logloss: 0.9572, test_pred_accuracy: 0.6988
# Epoch [84/100], Objective: 0.9524
# Epoch [85/100], train_pred_logloss: 0.9487, train_pred_accuracy: 0.6951, elbo_neg_ave: 0.9839, test_pred_logloss: 0.9540, test_pred_accuracy: 0.6974
# Epoch [85/100], Objective: 0.9518
# Epoch [86/100], train_pred_logloss: 0.9484, train_pred_accuracy: 0.6939, elbo_neg_ave: 0.9838, test_pred_logloss: 0.9541, test_pred_accuracy: 0.6973
# Epoch [86/100], Objective: 0.9513
# Epoch [87/100], train_pred_logloss: 0.9492, train_pred_accuracy: 0.6950, elbo_neg_ave: 0.9839, test_pred_logloss: 0.9549, test_pred_accuracy: 0.6970
# Epoch [87/100], Objective: 0.9511
# Epoch [88/100], train_pred_logloss: 0.9486, train_pred_accuracy: 0.6943, elbo_neg_ave: 0.9834, test_pred_logloss: 0.9540, test_pred_accuracy: 0.6978
# Epoch [88/100], Objective: 0.9511
# Epoch [89/100], train_pred_logloss: 0.9480, train_pred_accuracy: 0.6957, elbo_neg_ave: 0.9833, test_pred_logloss: 0.9542, test_pred_accuracy: 0.6974
# Epoch [89/100], Objective: 0.9506
# Epoch [90/100], train_pred_logloss: 0.9480, train_pred_accuracy: 0.6956, elbo_neg_ave: 0.9835, test_pred_logloss: 0.9527, test_pred_accuracy: 0.6985
# Epoch [90/100], Objective: 0.9510
# Epoch [91/100], train_pred_logloss: 0.9480, train_pred_accuracy: 0.6942, elbo_neg_ave: 0.9828, test_pred_logloss: 0.9537, test_pred_accuracy: 0.6960
# Epoch [91/100], Objective: 0.9502
# Epoch [92/100], train_pred_logloss: 0.9481, train_pred_accuracy: 0.6956, elbo_neg_ave: 0.9833, test_pred_logloss: 0.9537, test_pred_accuracy: 0.6977
# Epoch [92/100], Objective: 0.9504
# Epoch [93/100], train_pred_logloss: 0.9473, train_pred_accuracy: 0.6954, elbo_neg_ave: 0.9820, test_pred_logloss: 0.9536, test_pred_accuracy: 0.6997
# Epoch [93/100], Objective: 0.9497
# Epoch [94/100], train_pred_logloss: 0.9464, train_pred_accuracy: 0.6962, elbo_neg_ave: 0.9825, test_pred_logloss: 0.9546, test_pred_accuracy: 0.7002
# Epoch [94/100], Objective: 0.9499
# Epoch [95/100], train_pred_logloss: 0.9462, train_pred_accuracy: 0.6949, elbo_neg_ave: 0.9823, test_pred_logloss: 0.9538, test_pred_accuracy: 0.6950
# Epoch [95/100], Objective: 0.9497
# Epoch [96/100], train_pred_logloss: 0.9473, train_pred_accuracy: 0.6959, elbo_neg_ave: 0.9818, test_pred_logloss: 0.9519, test_pred_accuracy: 0.6982
# Epoch [96/100], Objective: 0.9494
# Epoch [97/100], train_pred_logloss: 0.9465, train_pred_accuracy: 0.6941, elbo_neg_ave: 0.9815, test_pred_logloss: 0.9535, test_pred_accuracy: 0.6986
# Epoch [97/100], Objective: 0.9490
# Epoch [98/100], train_pred_logloss: 0.9469, train_pred_accuracy: 0.6944, elbo_neg_ave: 0.9816, test_pred_logloss: 0.9522, test_pred_accuracy: 0.6991
# Epoch [98/100], Objective: 0.9493
# Epoch [99/100], train_pred_logloss: 0.9467, train_pred_accuracy: 0.6966, elbo_neg_ave: 0.9810, test_pred_logloss: 0.9503, test_pred_accuracy: 0.6981
# Epoch [99/100], Objective: 0.9487
# Epoch [100/100], train_pred_logloss: 0.9466, train_pred_accuracy: 0.6953, elbo_neg_ave: 0.9811, test_pred_logloss: 0.9524, test_pred_accuracy: 0.6977
# Epoch [100/100], Objective: 0.9484
# Done submitting jobs!

# %%
# result2 = subprocess.run(["python", "make_table_3.py"],capture_output=True)

# %%
import sys
sys.stdout.encoding
# Out:
# 'UTF-8'

# %%
# # Save stdout and stderr to files
# with open('output.txt', 'w') as f:
#     f.write("Standard Output:\n")
#     f.write(result.stdout)

# with open('error.txt', 'w') as f:
#     f.write("Standard Error:\n")
#     f.write(result.stderr)

# %%
# with open('training_output.txt', 'w') as f:
#     f.write("Arguments:\n")
#     f.write(f"{result.args}\n\n")

#     f.write("Return Code:\n")
#     f.write(f"{result.returncode}\n\n")

#     f.write("Standard Output:\n")
#     f.write(result.stdout)

#     f.write("\nStandard Error:\n")
#     f.write(result.stderr)

# %%
result
# Out:
# CompletedProcess(args=['python', 'submit_mnist_experiment.py'], returncode=0, stdout='d:\\Maths_Y4\\Project\\Bayesian-Neural-Network-Project\\Rebuilding_Slang\npython d:\\Maths_Y4\\Project\\Bayesian-Neural-Network-Project\\Rebuilding_Slang\\run_experiment.py --name="slang_mnist_experiment" --variant="L_2" --method="SLANG_COMPLETE" --cv=0\nargs: Namespace(name=\'slang_mnist_experiment\', variant=\'L_2\', method=\'SLANG_COMPLETE\', cv=0)\n\n  0%|          | 0.00/9.91M [00:00<?, ?B/s]\n  0%|          | 32.8k/9.91M [00:00<00:31, 313kB/s]\n  1%|          | 98.3k/9.91M [00:00<00:20, 477kB/s]\n  2%|â–         | 197k/9.91M [00:00<00:14, 687kB/s] \n  2%|â–         | 197k/9.91M [00:00<00:15, 614kB/s] Job python d:\\Maths_Y4\\Project\\Bayesian-Neural-Network-Project\\Rebuilding_Slang\\run_experiment.py --name="slang_mnist_experiment" --variant="L_2" --method="SLANG_COMPLETE" --cv=0 failed to submit\nDone submitting jobs!\n', stderr='INFO:artemis:========== Running Experiment: slang_complete.slang_mnist_experiment.L_2 ==========\nTraceback (most recent call last):\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\torchvision\\datasets\\utils.py", line 32, in _urlretrieve\n    pbar.update(len(chunk))\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\tqdm\\std.py", line 1242, in update\n    self.refresh(lock_args=self.lock_args)\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\tqdm\\std.py", line 1347, in refresh\n    self.display()\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\tqdm\\std.py", line 1495, in display\n    self.sp(self.__str__() if msg is None else msg)\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\tqdm\\std.py", line 459, in print_status\n    fp_write(\'\\r\' + s + (\' \' * max(last_len[0] - len_s, 0)))\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\tqdm\\std.py", line 452, in fp_write\n    fp.write(str(s))\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\tqdm\\utils.py", line 196, in inner\n    return func(*args, **kwargs)\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\artemis\\general\\display.py", line 202, in write\n    self.log.write(message)\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\encodings\\cp1252.py", line 19, in encode\n    return codecs.charmap_encode(input,self.errors,encoding_table)[0]\nUnicodeEncodeError: \'charmap\' codec can\'t encode character \'\\u258f\' in position 6: character maps to <undefined>\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "d:\\Maths_Y4\\Project\\Bayesian-Neural-Network-Project\\Rebuilding_Slang\\run_experiment.py", line 35, in <module>\n    experiments.slang_complete.get_variant(args.name).get_variant(args.variant).run()\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\artemis\\experiments\\experiments.py", line 107, in run\n    exp_rec = run_and_record(\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\artemis\\experiments\\experiment_record.py", line 669, in run_and_record\n    result = function()\n  File "d:\\Maths_Y4\\Project\\Bayesian-Neural-Network-Project\\Rebuilding_Slang\\slang_mnist_complete.py", line 77, in slang_complete\n    data = Dataset(data_set=val_data_set, data_folder=DEFAULT_DATA_FOLDER)\n  File "d:\\Maths_Y4\\Project\\Bayesian-Neural-Network-Project\\Rebuilding_Slang\\lib\\datasets.py", line 46, in __init__\n    full_train_set = dset.MNIST(root = data_folder,\n  File "c:\\Users\\peter\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\torchvision\\datasets\\mnist.py", line 100, in __init__\n    self.download()\n  File "c:\\Users\\ ...
